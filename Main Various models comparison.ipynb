# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Models and their evaluation metrics stored in a dictionary
models = ['FFNN', 'Nu-SVR', 'Adaboost', 'GPR', 'SGDBoost', 'WKNN', 'Ensemble']
evaluation_metrics = {
    'Nu-SVR': {'MAE': 0.000165794,  'RMSE': 0.000214267, 'R2': 0.959263572},
    'Adaboost': {'MAE': 0.000182879,  'RMSE': 0.000231826, 'R2': 0.952313235},
    'SGDBoost': {'MAE': 0.021647456, 'RMSE': 0.035185892, 'R2': 0.921828989},
    'GPR': {'MAE': 0.000046940, 'RMSE': 0.000113295, 'R2': 0.988610762},
    'WKNN': {'MAE': 0.031259705, 'RMSE': 0.047282549, 'R2': 0.858840420},
    'FFNN': {'MAE': 0.000211201, 'RMSE': 0.000307023, 'R2': 0.916359807},
    'Ensemble': {'MAE': 0.000060397, 'RMSE': 0.000129691, 'R2': 0.985075750}
}


# Create a figure with a size of (12, 18) to accommodate the plot
fig, axes = plt.subplots(len(evaluation_metrics['FFNN']), 1, figsize=(12, 18), sharex=True)

# Dictionary to map each metric to its appropriate scale
metric_scales = {'MAE': 'log', 'RMSE': 'log', 'R2': 'linear'}

# Define a gradient color map
colors = plt.cm.coolwarm(np.linspace(0, 1, len(models)))

for i, metric in enumerate(evaluation_metrics['FFNN'].keys()):
    values = [evaluation_metrics[model][metric] for model in models]
    ax = axes[i]
    bars = ax.bar(np.arange(len(models)), values, width=0.4, alpha=0.8, color=colors)

    ax.set_title(metric, fontsize=16)
    ax.set_ylabel(list(metric_scales.keys())[i], fontsize=12)
    ax.tick_params(axis='both', which='major', labelsize=8)
    ax.set_xticks(np.arange(len(models)))
    ax.set_xticklabels(models, rotation=45, ha='right', fontsize=12)

    if metric == 'R2':
        ax.set_ylim(0, 1)

    ax.set_yscale(metric_scales[metric])

    for bar, model, color in zip(bars, models, colors):
        height = bar.get_height()
        ax.text(
            bar.get_x() + bar.get_width() / 2, height, f'{height:.6f}',
            ha='center', va='bottom', fontsize=8
        )

# Set the overall title of the plot
plt.suptitle('Machine Learning Models Comparisons Based on Compositional Data', fontsize=18)

# Adjust layout to prevent overlapping and increase vertical space
plt.tight_layout(pad=1.0)

# Add padding between the subtitle and the plots
plt.subplots_adjust(top=0.95)

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Models and their evaluation metrics stored in a dictionary
models = ['FFNN', 'Nu-SVR', 'Adaboost', 'GPR', 'SGDBoost', 'WKNN', 'WANG', 'HEIDARYAN',]
evaluation_metrics = {
    'Nu-SVR': {'MAE': 0.009227765, 'RMSE': 0.054464792, 'R2': 0.812698917},
    'Adaboost': {'MAE': 0.046765985, 'RMSE': 0.058353729, 'R2': 0.784996352},
    'SGDBoost': {'MAE': 0.015149476, 'MAPE': 2.019616264, 'RMSE': 0.035758821, 'R2': 0.919262558},
    'GPR': {'MAE': 0.009098067, 'RMSE': 0.042615566, 'R2': 0.885331241},
    'WKNN': {'MAE': 0.007058686, 'RMSE': 0.027930132, 'R2': 0.950744518},
    'FFNN': {'MAE': 0.000211201, 'RMSE': 0.000307023, 'R2': 0.916359807},
    'WANG': {'MAE': 0.025269474290919598, 'RMSE': 0.029178769875953612, 'R2': 0.9426626561851833},
    'HEIDARYAN': {'MAE':0.03471391273896028, 'RMSE': 0.04362333864327349, 'R2': 0.8718432712052226},
}




# Create a figure with a size of (12, 18) to accommodate the plot
fig, axes = plt.subplots(len(evaluation_metrics['FFNN']), 1, figsize=(12, 18), sharex=True)

# Dictionary to map each metric to its appropriate scale
metric_scales = {'MAE': 'log', 'RMSE': 'log', 'R2': 'linear'}

# Define a gradient color map
colors = plt.cm.coolwarm(np.linspace(0, 1, len(models)))

for i, metric in enumerate(evaluation_metrics['FFNN'].keys()):
    values = [evaluation_metrics[model][metric] for model in models]
    ax = axes[i]
    bars = ax.bar(np.arange(len(models)), values, width=0.4, alpha=0.8, color=colors)

    ax.set_title(metric, fontsize=16)
    ax.set_ylabel(list(metric_scales.keys())[i], fontsize=12)
    ax.tick_params(axis='both', which='major', labelsize=8)
    ax.set_xticks(np.arange(len(models)))
    ax.set_xticklabels(models, rotation=45, ha='right', fontsize=12)

    if metric == 'R2':
        ax.set_ylim(0, 1)

    ax.set_yscale(metric_scales[metric])

    for bar, model, color in zip(bars, models, colors):
        height = bar.get_height()
        ax.text(
            bar.get_x() + bar.get_width() / 2, height, f'{height:.6f}',
            ha='center', va='bottom', fontsize=8
        )

# Set the overall title of the plot
plt.suptitle('Machine Learning Models Comparisons Based on Pseudo Reduced Values', fontsize=18)

# Adjust layout to prevent overlapping and increase vertical space
plt.tight_layout(pad=1.0)

# Add padding between the subtitle and the plots
plt.subplots_adjust(top=0.95)

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Models and their evaluation metrics stored in a dictionary
models = ['FFNN', 'Nu-SVR', 'Adaboost', 'GPR', 'SGDBoost', 'WKNN', 'WANG', 'HEIDARYAN',]
evaluation_metrics = {
    'Nu-SVR': {'MAE': 0.008886140,  'RMSE': 0.043069518, 'R2': 0.882875265},
    'Adaboost': {'MAE': 0.049445539, 'RMSE': 0.059849008, 'R2': 0.773836505},
    'SGDBoost': {'MAE': 0.015149476, 'RMSE': 0.035758821, 'R2': 0.919262558},
    'GPR': {'MAE': 0.009098067, 'RMSE': 0.042615566, 'R2': 0.885331241},
    'WKNN': {'MAE': 0.007058686, 'RMSE': 0.027930132, 'R2': 0.950744518},
    'FFNN': {'MAE': 0.007295342, 'RMSE': 0.028537101, 'R2': 0.948580448},
    'WANG': {'MAE': 0.025269474290919598, 'RMSE': 0.029178769875953612, 'R2': 0.9426626561851833},
    'HEIDARYAN': {'MAE':0.03471391273896028, 'RMSE': 0.04362333864327349, 'R2': 0.8718432712052226},
}



# Create a figure with a size of (12, 18) to accommodate the plot
fig, axes = plt.subplots(len(evaluation_metrics['FFNN']), 1, figsize=(12, 18), sharex=True)

# Dictionary to map each metric to its appropriate scale
metric_scales = {'MAE': 'log', 'RMSE': 'log', 'R2': 'linear'}

# Define a gradient color map
colors = plt.cm.coolwarm(np.linspace(0, 1, len(models)))

for i, metric in enumerate(evaluation_metrics['FFNN'].keys()):
    values = [evaluation_metrics[model][metric] for model in models]
    ax = axes[i]
    bars = ax.bar(np.arange(len(models)), values, width=0.4, alpha=0.8, color=colors)

    ax.set_title(metric, fontsize=16)
    ax.set_ylabel(list(metric_scales.keys())[i], fontsize=12)
    ax.tick_params(axis='both', which='major', labelsize=8)
    ax.set_xticks(np.arange(len(models)))
    ax.set_xticklabels(models, rotation=45, ha='right', fontsize=12)

    if metric == 'R2':
        ax.set_ylim(0, 1)

    ax.set_yscale(metric_scales[metric])

    for bar, model, color in zip(bars, models, colors):
        height = bar.get_height()
        ax.text(
            bar.get_x() + bar.get_width() / 2, height, f'{height:.6f}',
            ha='center', va='bottom', fontsize=8
        )

# Set the overall title of the plot
plt.suptitle('Machine Learning Models Comparisons Based on Corrected Pseudo Reduced Values', fontsize=18)

# Adjust layout to prevent overlapping and increase vertical space
plt.tight_layout(pad=1.0)

# Add padding between the subtitle and the plots
plt.subplots_adjust(top=0.95)

# Show the plots
plt.show()
