# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('df_for_models.csv')

# Define the selected features and target variable
selected_features = ['T (K)', 'P (MPa)', 'methane', 'ethane', 
                     'propane', 'butane', 'pentane', 'ipentane',
                     'hexane', 'heptane', 'octane', 'nonane', 'decane',
                     'helium', 'oxygen', 'nitrogen', 'water', 'argon',
                     'hydrogen', 'H2S', 'CO2']
target_variable = 'z'

# Visualize relationships between continuous features and the target variable using swarm plots
for feature in selected_features:
    if data[feature].dtype != 'object':  # Check for continuous features
        plt.figure(figsize=(8, 6))
        sns.swarmplot(x=target_variable, y=feature, data=data)
        plt.title(f"{feature} vs {target_variable}")
        plt.xlabel(target_variable)
        plt.ylabel(feature)
        plt.show()
# Out:
# C:\Users\okola\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 95.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\okola\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\okola\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 88.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\okola\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 95.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
